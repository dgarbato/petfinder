# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_all = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp April\Python\web_scraping_project\data prepared for analysis\cleaned data\df_all.csv')

# %%
def proc_freq(df,variable_):  #Note variable_ must be given in quotes example: variable_ = 'xyz'
    datax = df[variable_].value_counts().sort_index()
    
    datay = pd.DataFrame({
        variable_: datax.index,
        'Frequency': datax.values,
        'Percent': ((datax.values/datax.values.sum())*100).round(2),
        'Cumulative Frequency': datax.values.cumsum(),
        'Cumulative Percent': ((datax.values.cumsum()/datax.values.sum())*100).round(2)   })
    
    #datay.set_index(variable_)
    
    return(datay.set_index(variable_))

# %%
def proc_freq_no_ind(df,variable_):  #Note variable_ must be given in quotes example: variable_ = 'xyz'
    datax = df[variable_].value_counts().sort_index()
    
    datay = pd.DataFrame({
        variable_: datax.index,
        'Frequency': datax.values,
        'Percent': ((datax.values/datax.values.sum())*100).round(2),
        'Cumulative Frequency': datax.values.cumsum(),
        'Cumulative Percent': ((datax.values.cumsum()/datax.values.sum())*100).round(2)   })
    
    #datay.set_index(variable_)
    
    return(datay)

# %%
df_thirty = df_all.loc[df_all.thirty_days,:]
df_thirty['days_on_site'] = 'Thirty Days Plus'

df_other_days = df_all.loc[df_all.other_days,:]
df_other_days['days_on_site'] = 'Less Than Thirty Days'

df_thirty_k = df_thirty.loc[df_thirty['age']=='Kitten',:]
df_other_days_k = df_other_days.loc[df_other_days['age']=='Kitten',:]

df_other_days['days_on_site'].value_counts()

combined_df = pd.concat([df_other_days,df_thirty], axis = 0, sort=False)

combined_df_k = combined_df.loc[combined_df['age']=='Kitten',:]

combined_df['days_on_site'].value_counts()
# Out:
# <ipython-input-7-46c2b61a3dfb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_thirty['days_on_site'] = 'Thirty Days Plus'
# <ipython-input-7-46c2b61a3dfb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_other_days['days_on_site'] = 'Less Than Thirty Days'
# Thirty Days Plus         1433
# Less Than Thirty Days     587
# Name: days_on_site, dtype: int64

# %%
def func_freq(lst):
    for el in lst:
        print('Thirty Days Plus')
        print(proc_freq(df_thirty,el))
        print()
        print('Less Than Thirty Days')
        print(proc_freq(df_other_days,el))
        print('_'*75)

# %%
cols=['age','sex','Tabby','without_story','coat_length_miss','coat_length', 'more_than_1_cat','breed_type','video', \
      'pictures','num_pictures']
func_freq(cols)
# Out:
# Thirty Days Plus
#         Frequency  Percent  Cumulative Frequency  Cumulative Percent
# age
# Adult         589    41.10                   589               41.10
# Kitten        374    26.10                   963               67.20
# Senior         98     6.84                  1061               74.04
# Young         372    25.96                  1433              100.00
#
# Less Than Thirty Days
#         Frequency  Percent  Cumulative Frequency  Cumulative Percent
# age
# Adult          96    16.35                    96               16.35
# Kitten        362    61.67                   458               78.02
# Senior         25     4.26                   483               82.28
# Young         104    17.72                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#         Frequency  Percent  Cumulative Frequency  Cumulative Percent
# sex
# Female        759    52.97                   759               52.97
# Male          674    47.03                  1433              100.00
#
# Less Than Thirty Days
#         Frequency  Percent  Cumulative Frequency  Cumulative Percent
# sex
# Female        271    46.17                   271               46.17
# Male          316    53.83                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#        Frequency  Percent  Cumulative Frequency  Cumulative Percent
# Tabby
# False       1126    78.58                  1126               78.58
# True         307    21.42                  1433              100.00
#
# Less Than Thirty Days
#        Frequency  Percent  Cumulative Frequency  Cumulative Percent
# Tabby
# False        443    75.47                   443               75.47
# True         144    24.53                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#                Frequency  Percent  Cumulative Frequency  Cumulative Percent
# without_story
# False               1410    98.39                  1410               98.39
# True                  23     1.61                  1433              100.00
#
# Less Than Thirty Days
#                Frequency  Percent  Cumulative Frequency  Cumulative Percent
# without_story
# False                557    94.89                   557               94.89
# True                  30     5.11                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#                   Frequency  Percent  Cumulative Frequency  Cumulative Percent
# coat_length_miss
# Hairless                  1     0.07                     1                0.07
# Long                     10     0.70                    11                0.77
# Medium                   42     2.93                    53                3.70
# Short                   907    63.29                   960               66.99
# unknown                 473    33.01                  1433              100.00
#
# Less Than Thirty Days
#                   Frequency  Percent  Cumulative Frequency  Cumulative Percent
# coat_length_miss
# Hairless                  1     0.17                     1                0.17
# Long                     17     2.90                    18                3.07
# Medium                   31     5.28                    49                8.35
# Short                   393    66.95                   442               75.30
# unknown                 145    24.70                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#              Frequency  Percent  Cumulative Frequency  Cumulative Percent
# coat_length
# Hairless             1     0.10                     1                0.10
# Long                10     1.04                    11                1.15
# Medium              42     4.38                    53                5.52
# Short              907    94.48                   960              100.00
#
# Less Than Thirty Days
#              Frequency  Percent  Cumulative Frequency  Cumulative Percent
# coat_length
# Hairless             1     0.23                     1                0.23
# Long                17     3.85                    18                4.07
# Medium              31     7.01                    49               11.09
# Short              393    88.91                   442              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#                  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# more_than_1_cat
# False                 1310    91.42                  1310               91.42
# True                   123     8.58                  1433              100.00
#
# Less Than Thirty Days
#                  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# more_than_1_cat
# False                  498    84.84                   498               84.84
# True                    89    15.16                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#             Frequency  Percent  Cumulative Frequency  Cumulative Percent
# breed_type
# DLH                17     1.19                    17                1.19
# DSH              1283    89.53                  1300               90.72
# Other             133     9.28                  1433              100.00
#
# Less Than Thirty Days
#             Frequency  Percent  Cumulative Frequency  Cumulative Percent
# breed_type
# DLH                19     3.24                    19                3.24
# DSH               534    90.97                   553               94.21
# Other              34     5.79                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#        Frequency  Percent  Cumulative Frequency  Cumulative Percent
# video
# False       1301    90.79                  1301               90.79
# True         132     9.21                  1433              100.00
#
# Less Than Thirty Days
#        Frequency  Percent  Cumulative Frequency  Cumulative Percent
# video
# False        540    91.99                   540               91.99
# True          47     8.01                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#           Frequency  Percent  Cumulative Frequency  Cumulative Percent
# pictures
# False           268     18.7                   268                18.7
# True           1165     81.3                  1433               100.0
#
# Less Than Thirty Days
#           Frequency  Percent  Cumulative Frequency  Cumulative Percent
# pictures
# False           166    28.28                   166               28.28
# True            421    71.72                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#               Frequency  Percent  Cumulative Frequency  Cumulative Percent
# num_pictures
# 0                   268    18.70                   268               18.70
# 2                   228    15.91                   496               34.61
# 3                   318    22.19                   814               56.80
# 4                   153    10.68                   967               67.48
# 5                   204    14.24                  1171               81.72
# 6                   262    18.28                  1433              100.00
#
# Less Than Thirty Days
#               Frequency  Percent  Cumulative Frequency  Cumulative Percent
# num_pictures
# 0                   166    28.28                   166               28.28
# 1                     6     1.02                   172               29.30
# 2                    74    12.61                   246               41.91
# 3                   112    19.08                   358               60.99
# 4                    71    12.10                   429               73.08
# 5                    52     8.86                   481               81.94
# 6                   106    18.06                   587              100.00
# ___________________________________________________________________________

# %%
def func_freq_k(lst):
    for el in lst:
        print('Thirty Days Plus Kittens')
        print(proc_freq(df_thirty_k,el))
        print()
        print('Less Than Thirty Days Kittens')
        print(proc_freq(df_other_days_k,el))
        print('_'*75)

# %%
cols=['age','sex','Tabby','without_story','coat_length_miss','coat_length', 'more_than_1_cat','breed_type','video', \
      'pictures','num_pictures']
func_freq_k(cols)
