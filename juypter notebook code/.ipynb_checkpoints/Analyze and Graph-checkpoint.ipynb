# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df_all = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp April\Python\web_scraping_project\data prepared for analysis\cleaned data\df_all.csv')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2020 non-null   int64
#  1   cat_name                2020 non-null   object
#  2   num_images              2020 non-null   int64
#  3   num_videos              2020 non-null   int64
#  4   age                     2020 non-null   object
#  5   color                   1726 non-null   object
#  6   sex                     2020 non-null   object
#  7   good_in_a_home_with     1265 non-null   object
#  8   adoption_fee            364 non-null    object
#  9   prefers_a_home_without  303 non-null    object
#  10  coat_length             1402 non-null   object
#  11  pet_story_num_words     2020 non-null   float64
#  12  rescue_group            2020 non-null   object
#  13  data_set                2020 non-null   object
#  14  cat_id                  2020 non-null   object
#  15  thirty_days             2020 non-null   bool
#  16  Tabby                   2020 non-null   bool
#  17  without_story           2020 non-null   bool
#  18  coat_length_miss        2020 non-null   object
#  19  more_than_1_cat         2020 non-null   bool
#  20  video                   2020 non-null   bool
#  21  num_pictures            2020 non-null   int64
#  22  pictures                2020 non-null   bool
#  23  breed_type              2020 non-null   object
#  24  Days_On_Site            2020 non-null   object
#  25  color_miss              1726 non-null   object
#  26  color_new               2020 non-null   object
# dtypes: bool(6), float64(1), int64(4), object(16)
# memory usage: 343.4+ KB

# %%
def proc_freq(df,variable_):  #Note variable_ must be given in quotes example: variable_ = 'xyz'
    datax = df[variable_].value_counts().sort_index()
    
    datay = pd.DataFrame({
        variable_: datax.index,
        'Frequency': datax.values,
        'Percent': ((datax.values/datax.values.sum())*100).round(2),
        'Cumulative_Frequency': datax.values.cumsum(),
        'Cumulative_Percent': ((datax.values.cumsum()/datax.values.sum())*100).round(2)   })
    
    #datay.set_index(variable_)
    #return(datay.set_index(variable_))
    return(datay)

# %%
def compare_percent(var_):
    df_30 = df_all.loc[df_all.thirty_days==True,[var_]]
    df_30 = proc_freq(df_30,var_)
    df_30 = df_all.loc[df_all.thirty_days==True,[var_]]
    df_30 = proc_freq(df_30,var_)
    df_30 = df_30.loc[:,[var_,'Percent']]
    df_30['Days_On_Site'] = 'Thirty Days Plus'

    df_other = df_all.loc[df_all.thirty_days==False,[var_]]
    df_other = proc_freq(df_other,var_)
    df_other = df_other.loc[:,[var_,'Percent']]
    df_other['Days_On_Site'] = 'Less Than Thirty Days'

    combined = pd.concat([df_other,df_30], axis = 0, sort=False)
    return(combined)

# %%
sns.set_style('darkgrid')
color_order=['Kitten','Young','Adult','Senior']
 
chart = sns.countplot(x='age', data = df_all, hue='Days_On_Site',order=color_order, palette='Blues')

chart.set(xlabel="Age", ylabel = "Number Of Cats")

chart.set(title='Number Of Cats By Age')

plt.figure(figsize = (15,8))

plt.savefig('num_cats_by_age.png', dpi=300)

# %%
combined= compare_percent('age')
sns.set_style('darkgrid')

pct = combined.groupby(['Days_On_Site','age'])['Percent'].mean()
print(type(pct))
pct = pct.reset_index()
print(pct)

color_order=['Kitten','Young','Adult','Senior']
chart = sns.factorplot('age', 'Percent', col='Days_On_Site', data=combined, kind='bar', ci=False, order=color_order)

chart.set(xlabel="Age", ylabel = "Percent of 100")

plt.figure(figsize = (15,8))

chart.set_titles(col_template= '{col_name}');

# %%
'Days_On_Site'
pct = combined.groupby(['Days_On_Site','age'])['Percent'].mean()
pct
# Out:
# Days_On_Site           age
# Less Than Thirty Days  Adult     16.35
#                        Kitten    61.67
#                        Senior     4.26
#                        Young     17.72
# Thirty Days Plus       Adult     41.10
#                        Kitten    26.10
#                        Senior     6.84
#                        Young     25.96
# Name: Percent, dtype: float64

# %%
combined= compare_percent('age')
sns.set_style('darkgrid')

# pct = combined.groupby(['Days_On_Site','age'])['Percent'].mean()
# print(type(pct))
# pct = pct.reset_index()
# print(pct)

color_order=['Kitten','Young','Adult','Senior']
chart = sns.factorplot(y='age', x='Percent', col='Days_On_Site', data=combined, kind='bar', ci=False, order=color_order)

chart.set(ylabel="Age", xlabel = "Percent of 100")

plt.figure(figsize = (15,8))

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
combined= compare_percent('age')
sns.set_style('darkgrid')

# pct = combined.groupby(['Days_On_Site','age'])['Percent'].mean()
# print(type(pct))
# pct = pct.reset_index()
# print(pct)

color_order=['Kitten','Young','Adult','Senior']
chart = sns.factorplot(y='age', x='Percent', col='Days_On_Site', data=combined, kind='bar', ci=False, order=color_order,color='skyblue')

chart.set(ylabel="Age", xlabel = "Percent of 100")

plt.figure(figsize = (15,8))

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
combined= compare_percent('color_new')
sns.set_style('darkgrid')

# pct = combined.groupby(['Days_On_Site','age'])['Percent'].mean()
# print(type(pct))
# pct = pct.reset_index()
# print(pct)

#sns.set_color_codes("pastel")


sns.reset_orig

chart = sns.factorplot(y='color_new', x='Percent', col='Days_On_Site', data=combined, kind='bar', ci=False, )

chart.set(xlabel="Percent of 100", ylabel = "Coat Color")

plt.figure(figsize = (15,8))

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
combined= compare_percent('sex')
sns.set_style('darkgrid')

chart = sns.factorplot( y='Percent', x='sex', col='Days_On_Site', data=combined, kind='bar',color='skyblue')
chart.set(ylabel = "Percent Of 100", xlabel="Gender")

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
combined= compare_percent('more_than_1_cat')
sns.set_style('darkgrid')

chart = sns.factorplot('more_than_1_cat', 'Percent', col='Days_On_Site', data=combined, kind='bar',color='skyblue')
chart.set(xlabel="More Than One Cat", ylabel = "Percent Of 100")

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
combined= compare_percent('coat_length')
sns.set_style('darkgrid')

chart = sns.factorplot(x='coat_length', y='Percent', col='Days_On_Site', data=combined, kind='bar',color='skyblue')
chart.set(xlabel="Coat Length", ylabel = "Percent Of 100")

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
combined= compare_percent('video')
sns.set_style('darkgrid')

chart = sns.factorplot('video', 'Percent', col='Days_On_Site', data=combined, kind='bar',color='skyblue')
chart.set(xlabel="Video of Cat", ylabel = "Percent Of 100")

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
combined= compare_percent('breed_type')
sns.set_style('darkgrid')

chart = sns.factorplot(x='breed_type', y='Percent', col='Days_On_Site', data=combined, kind='bar',color='skyblue')
chart.set(xlabel="Breed", ylabel = "Percent Of 100")

chart.set_titles(col_template= '{col_name}');
# Out:
# C:\Users\dgarb\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df = df_all.loc[:,['Days_On_Site','pet_story_num_words']]
data_wide = df.pivot(columns='Days_On_Site',
                     values='pet_story_num_words')
g = sns.kdeplot(data=data_wide)
g.set_title('Number of Words in Pet Narrative' )
# Out:
# Text(0.5, 1.0, 'Number of Words in Pet Narrative')

# %%
sns.boxplot(x='Days_On_Site', y='pet_story_num_words',
            
            data=df_all)
#hue="smoker", palette=["m", "g"],
sns.despine(offset=10, trim=True)

# %%
df = df_all.loc[:,['Days_On_Site','num_images']]
data_wide = df.pivot(columns='Days_On_Site',
                     values='num_images')
g = sns.kdeplot(data=data_wide)
g.set_title('Number of Pictures')
# Out:
# Text(0.5, 1.0, 'Number of Pictures')

# %%
plt.style.use('seaborn-darkgrid')
df = df_all.loc[:,['Days_On_Site','pet_story_num_words']]
data_wide = df.pivot(columns='Days_On_Site',
                     values='pet_story_num_words')
data_wide.head()

# calling density() to make
# multiple density plot 
data_wide.plot.density(figsize = (15, 8),
                       linewidth = 4)
  
plt.xlabel("Pet Story Number of Words")
data_wide
# Out:
# Days_On_Site  Less Than Thirty Days  Thirty Days Plus
# 0                              89.0               NaN
# 1                              89.0               NaN
# 2                             126.0               NaN
# 3                             313.0               NaN
# 4                             149.0               NaN
# ...                             ...               ...
# 2015                            NaN             164.0
# 2016                            NaN             225.0
# 2017                            NaN             102.0
# 2018                            NaN              11.0
# 2019                            NaN               0.0
#
# [2020 rows x 2 columns]

# %%
plt.style.use('seaborn-darkgrid')

df = df_all.loc[:,['Days_On_Site','num_images']]
data_wide = df.pivot(columns='Days_On_Site',
                     values='num_images')
data_wide.head()

# calling density() to make
# multiple density plot 
data_wide.plot.density(figsize = (15,8),
                       linewidth = 4)

#plt.figure(figsize = ((7, 7))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Create two separate DataFrames one for thirty days and one for less than thirty days for use in proc_freq function.

# %%
df_thirty = df_all.loc[df_all.thirty_days==True,:]
df_other_days = df_all.loc[df_all.thirty_days==False,:]


df_thirty_k = df_thirty.loc[df_thirty['age']=='Kitten',:]
df_other_days_k = df_other_days.loc[df_other_days['age']=='Kitten',:]

# %%
def func_freq(lst):
    for el in lst:
        print('Thirty Days Plus')
        print(proc_freq(df_thirty,el))
        print()
        print('Less Than Thirty Days')
        print(proc_freq(df_other_days,el))
        print('_'*75)

# %%
cols=['age','sex','Tabby','without_story','coat_length_miss','coat_length', 'more_than_1_cat','breed_type','video', \
      'pictures','num_pictures']
func_freq(cols)
# Out:
# Thirty Days Plus
#       age  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0   Adult        589    41.10                   589               41.10
# 1  Kitten        374    26.10                   963               67.20
# 2  Senior         98     6.84                  1061               74.04
# 3   Young        372    25.96                  1433              100.00
#
# Less Than Thirty Days
#       age  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0   Adult         96    16.35                    96               16.35
# 1  Kitten        362    61.67                   458               78.02
# 2  Senior         25     4.26                   483               82.28
# 3   Young        104    17.72                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#       sex  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Female        759    52.97                   759               52.97
# 1    Male        674    47.03                  1433              100.00
#
# Less Than Thirty Days
#       sex  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Female        271    46.17                   271               46.17
# 1    Male        316    53.83                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#    Tabby  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False       1126    78.58                  1126               78.58
# 1   True        307    21.42                  1433              100.00
#
# Less Than Thirty Days
#    Tabby  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        443    75.47                   443               75.47
# 1   True        144    24.53                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   without_story  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0         False       1410    98.39                  1410               98.39
# 1          True         23     1.61                  1433              100.00
#
# Less Than Thirty Days
#   without_story  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0         False        557    94.89                   557               94.89
# 1          True         30     5.11                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   coat_length_miss  Frequency  Percent  Cumulative Frequency  \
# 0         Hairless          1     0.07                     1
# 1             Long         10     0.70                    11
# 2           Medium         42     2.93                    53
# 3            Short        907    63.29                   960
# 4          unknown        473    33.01                  1433
#
#    Cumulative Percent
# 0                0.07
# 1                0.77
# 2                3.70
# 3               66.99
# 4              100.00
#
# Less Than Thirty Days
#   coat_length_miss  Frequency  Percent  Cumulative Frequency  \
# 0         Hairless          1     0.17                     1
# 1             Long         17     2.90                    18
# 2           Medium         31     5.28                    49
# 3            Short        393    66.95                   442
# 4          unknown        145    24.70                   587
#
#    Cumulative Percent
# 0                0.17
# 1                3.07
# 2                8.35
# 3               75.30
# 4              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   coat_length  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    Hairless          1     0.10                     1                0.10
# 1        Long         10     1.04                    11                1.15
# 2      Medium         42     4.38                    53                5.52
# 3       Short        907    94.48                   960              100.00
#
# Less Than Thirty Days
#   coat_length  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    Hairless          1     0.23                     1                0.23
# 1        Long         17     3.85                    18                4.07
# 2      Medium         31     7.01                    49               11.09
# 3       Short        393    88.91                   442              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   more_than_1_cat  Frequency  Percent  Cumulative Frequency  \
# 0           False       1310    91.42                  1310
# 1            True        123     8.58                  1433
#
#    Cumulative Percent
# 0               91.42
# 1              100.00
#
# Less Than Thirty Days
#   more_than_1_cat  Frequency  Percent  Cumulative Frequency  \
# 0           False        498    84.84                   498
# 1            True         89    15.16                   587
#
#    Cumulative Percent
# 0               84.84
# 1              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   breed_type  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        DLH         17     1.19                    17                1.19
# 1        DSH       1283    89.53                  1300               90.72
# 2      Other        133     9.28                  1433              100.00
#
# Less Than Thirty Days
#   breed_type  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        DLH         19     3.24                    19                3.24
# 1        DSH        534    90.97                   553               94.21
# 2      Other         34     5.79                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#    video  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False       1301    90.79                  1301               90.79
# 1   True        132     9.21                  1433              100.00
#
# Less Than Thirty Days
#    video  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        540    91.99                   540               91.99
# 1   True         47     8.01                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#   pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    False        268     18.7                   268                18.7
# 1     True       1165     81.3                  1433               100.0
#
# Less Than Thirty Days
#   pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    False        166    28.28                   166               28.28
# 1     True        421    71.72                   587              100.00
# ___________________________________________________________________________
# Thirty Days Plus
#    num_pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0             0        268    18.70                   268               18.70
# 1             2        228    15.91                   496               34.61
# 2             3        318    22.19                   814               56.80
# 3             4        153    10.68                   967               67.48
# 4             5        204    14.24                  1171               81.72
# 5             6        262    18.28                  1433              100.00
#
# Less Than Thirty Days
#    num_pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0             0        166    28.28                   166               28.28
# 1             1          6     1.02                   172               29.30
# 2             2         74    12.61                   246               41.91
# 3             3        112    19.08                   358               60.99
# 4             4         71    12.10                   429               73.08
# 5             5         52     8.86                   481               81.94
# 6             6        106    18.06                   587              100.00
# ___________________________________________________________________________

# %%
def func_freq_k(lst):
    for el in lst:
        print('Thirty Days Plus Kittens')
        print(proc_freq(df_thirty_k,el))
        print()
        print('Less Than Thirty Days Kittens')
        print(proc_freq(df_other_days_k,el))
        print('_'*75)

# %%
cols=['age','sex','Tabby','without_story','coat_length_miss','coat_length', 'more_than_1_cat','breed_type','video', \
      'pictures','num_pictures']
func_freq_k(cols)
# Out:
# Thirty Days Plus Kittens
#       age  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Kitten        374    100.0                   374               100.0
#
# Less Than Thirty Days Kittens
#       age  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Kitten        362    100.0                   362               100.0
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#       sex  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Female        192    51.34                   192               51.34
# 1    Male        182    48.66                   374              100.00
#
# Less Than Thirty Days Kittens
#       sex  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  Female        158    43.65                   158               43.65
# 1    Male        204    56.35                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#    Tabby  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        285     76.2                   285                76.2
# 1   True         89     23.8                   374               100.0
#
# Less Than Thirty Days Kittens
#    Tabby  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        281    77.62                   281               77.62
# 1   True         81    22.38                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   without_story  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0         False        369    98.66                   369               98.66
# 1          True          5     1.34                   374              100.00
#
# Less Than Thirty Days Kittens
#   without_story  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0         False        346    95.58                   346               95.58
# 1          True         16     4.42                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   coat_length_miss  Frequency  Percent  Cumulative Frequency  \
# 0             Long          2     0.53                     2
# 1           Medium         10     2.67                    12
# 2            Short        254    67.91                   266
# 3          unknown        108    28.88                   374
#
#    Cumulative Percent
# 0                0.53
# 1                3.21
# 2               71.12
# 3              100.00
#
# Less Than Thirty Days Kittens
#   coat_length_miss  Frequency  Percent  Cumulative Frequency  \
# 0             Long         10     2.76                    10
# 1           Medium         16     4.42                    26
# 2            Short        266    73.48                   292
# 3          unknown         70    19.34                   362
#
#    Cumulative Percent
# 0                2.76
# 1                7.18
# 2               80.66
# 3              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   coat_length  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        Long          2     0.75                     2                0.75
# 1      Medium         10     3.76                    12                4.51
# 2       Short        254    95.49                   266              100.00
#
# Less Than Thirty Days Kittens
#   coat_length  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        Long         10     3.42                    10                3.42
# 1      Medium         16     5.48                    26                8.90
# 2       Short        266    91.10                   292              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   more_than_1_cat  Frequency  Percent  Cumulative Frequency  \
# 0           False        323    86.36                   323
# 1            True         51    13.64                   374
#
#    Cumulative Percent
# 0               86.36
# 1              100.00
#
# Less Than Thirty Days Kittens
#   more_than_1_cat  Frequency  Percent  Cumulative Frequency  \
# 0           False        293    80.94                   293
# 1            True         69    19.06                   362
#
#    Cumulative Percent
# 0               80.94
# 1              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   breed_type  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        DLH          1     0.27                     1                0.27
# 1        DSH        328    87.70                   329               87.97
# 2      Other         45    12.03                   374              100.00
#
# Less Than Thirty Days Kittens
#   breed_type  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0        DLH         11     3.04                    11                3.04
# 1        DSH        328    90.61                   339               93.65
# 2      Other         23     6.35                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#    video  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        337    90.11                   337               90.11
# 1   True         37     9.89                   374              100.00
#
# Less Than Thirty Days Kittens
#    video  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0  False        342    94.48                   342               94.48
# 1   True         20     5.52                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#   pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    False         78    20.86                    78               20.86
# 1     True        296    79.14                   374              100.00
#
# Less Than Thirty Days Kittens
#   pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0    False        117    32.32                   117               32.32
# 1     True        245    67.68                   362              100.00
# ___________________________________________________________________________
# Thirty Days Plus Kittens
#    num_pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0             0         78    20.86                    78               20.86
# 1             2         59    15.78                   137               36.63
# 2             3         69    18.45                   206               55.08
# 3             4         51    13.64                   257               68.72
# 4             5         56    14.97                   313               83.69
# 5             6         61    16.31                   374              100.00
#
# Less Than Thirty Days Kittens
#    num_pictures  Frequency  Percent  Cumulative Frequency  Cumulative Percent
# 0             0        117    32.32                   117               32.32
# 1             1          5     1.38                   122               33.70
# 2             2         43    11.88                   165               45.58
# 3             3         53    14.64                   218               60.22
# 4             4         44    12.15                   262               72.38
# 5             5         28     7.73                   290               80.11
# 6             6         72    19.89                   362              100.00
# ___________________________________________________________________________

# %%
print(plt.style.available)
plt.style.use('default')

#plt.style.use("seaborn")
#plt.style.use("tableau-colorblind10")
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
