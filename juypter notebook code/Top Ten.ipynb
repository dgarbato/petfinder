# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_spec_needs= pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp April\Python\web_scraping_project\data prepared for analysis\cleaned data\df_spec_needs.csv')
df_spec_needs.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1 cat_name  num_images  num_videos     age  \
# 0        2020             0   Dougie           5           1  Senior
# 1        2021             1    Elias           6           1   Adult
#
#                  breed color    size     sex  ... spec_needs without_story  \
# 0  Domestic Short Hair   NaN  Medium  Female  ...       True         False
# 1  Domestic Short Hair   NaN  Medium    Male  ...       True         False
#
#   coat_length_miss color_miss more_than_1_cat video num_pictures  pictures  \
# 0          unknown    unknown           False  True            5      True
# 1          unknown    unknown           False  True            6      True
#
#   breed_type           Days_On_Site
# 0        DSH  Less Than Thirty Days
# 1        DSH  Less Than Thirty Days
#
# [2 rows x 34 columns]

# %%
mask = df_spec_needs.groupby(['rescue_group']).count()[['cat_id']].sort_values(by=['cat_id'],ascending=False) #> 1
mask
#list_mask = df_spec_needs.groupby(['rescue_group']).count()[['cat_id']].sort_values(by=['cat_id'],ascending=False).loc[mask.values,:].index

#final_mask = df_spec_needs['cat_id'].isin(list_mask)

#df_spec_needs.loc[final_mask,['cat_id','rescue_group'].groupby(['rescue_group']).count()
# Out:
#                                         cat_id
# rescue_group
# Cameron Animal Hospital Rescue               7
# CLAWS                                        6
# Final Hope Animal Rescue and Sanctuary       5
# Puppy Kitty NY City                          5
# Bobbi & the Strays                           4
# ...                                        ...
# Joyrides Rescue                              1
# Kittens and Barbells Rescue Inc.             1
# Lawyers In Defense of Animals (LIDA)         1
# Lend-a-Paw Inc.                              1
# JerseyCats                                   1
#
# [69 rows x 1 columns]

# %%
df_all2 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp April\Python\web_scraping_project\data prepared for analysis\cleaned data\df_all.csv')
df_all2.head(2)
# Out:
#    Unnamed: 0         cat_name  num_images  num_videos    age color     sex  \
# 0           0  Ashe and Billie           6           0  Adult   NaN  Female
# 1           1  Billie and Ashe           6           0  Adult   NaN  Female
#
#   characteristics good_in_a_home_with adoption_fee  ... thirty_days  \
# 0             NaN                 NaN          NaN  ...       False
# 1             NaN                 NaN          NaN  ...       False
#
#   without_story  coat_length_miss color_miss more_than_1_cat  video  \
# 0         False           unknown    unknown            True  False
# 1         False           unknown    unknown            True  False
#
#    num_pictures  pictures breed_type           Days_On_Site
# 0             6      True        DSH  Less Than Thirty Days
# 1             6      True        DSH  Less Than Thirty Days
#
# [2 rows x 26 columns]

# %%
df_all2.loc[df_all2['age']== 'Adult'].groupby(['rescue_group']).unique()[['cat_id']].sort_values(by=['cat_id'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-14b646bc9530> in <module>
# ----> 1 df_all2.loc[df_all2['age']== 'Adult'].groupby(['rescue_group']).unique()[['cat_id']].sort_values(by=['cat_id'],ascending=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'unique'
